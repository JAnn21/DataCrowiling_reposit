# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model

caltech_dir = "./data/test"
image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*.*")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)
    filenames.append(f)
    X.append(data)

X = np.array(X)
model = load_model('./model/multi_img_classification.model')
model.summary()
prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0

#이 비교는 그냥 파일들이 있으면 해당 파일과 비교. 카테고리와 함께 비교해서 진행하는 것은 _4 파일.
for i in prediction:
    pre_ans = i.argmax()  # 예측 레이블
    print(pre_ans)
    pre_ans_str = ''
    if pre_ans == 0: pre_ans_str = "그레이"
    elif pre_ans == 1: pre_ans_str = "말티즈"
    elif pre_ans == 2: pre_ans_str = "불독"
    elif pre_ans == 3: pre_ans_str = "비글"
    elif pre_ans == 4: pre_ans_str = "셰퍼드"
    elif pre_ans == 5: pre_ans_str = "시바견"
    elif pre_ans == 6: pre_ans_str = "시츄"
    elif pre_ans == 7: pre_ans_str = "요크셔"
    elif pre_ans == 8: pre_ans_str = "웰시"
    elif pre_ans == 9: pre_ans_str = "치와와"
    elif pre_ans == 10: pre_ans_str = "포메라니"
    elif pre_ans == 11: pre_ans_str = "푸들"
    elif pre_ans == 12: pre_ans_str = "허스키"
    else: pre_ans_str = "게"
    if i[0] >= 0.8 : print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[1] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
    if i[2] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[3] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[4] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[5] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[6] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[7] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[8] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[9] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[10] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[11] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[12] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    cnt += 1
    # print(i.argmax()) #얘가 레이블 [1. 0. 0.] 이런식으로 되어 있는 것을 숫자로 바꿔주는 것.
    # 즉 얘랑, 나중에 카테고리 데이터 불러와서 카테고리랑 비교를 해서 같으면 맞는거고, 아니면 틀린거로 취급하면 된다.
    # 이걸 한 것은 _4.py에.
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 13)                3341
# =================================================================
# Total params: 2,341,581
# Trainable params: 2,341,581
# Non-trainable params: 0
# _________________________________________________________________
# 3
# 해당 beagle.jpg이미지는 비글로 추정됩니다.
# 2
# 해당 bull.jpg이미지는 불독로 추정됩니다.
# 0
# 해당 gray.jpg이미지는 그레이로 추정됩니다.
# 1
# 해당 mar.jpg이미지는 말티즈으로 추정됩니다.
# 8
# 해당 셰퍼드.jpg이미지는 웰시로 추정됩니다.
# 5
# 해당 시바견.jpg이미지는 시바견로 추정됩니다.
# 6
# 해당 시츄.jpg이미지는 시츄로 추정됩니다.
# 5
# 해당 요크셔.jpg이미지는 시바견로 추정됩니다.
# 8
# 해당 웰시코기.jpg이미지는 웰시로 추정됩니다.
# 9
# 해당 치와와.jpg이미지는 치와와로 추정됩니다.
# 10
# 해당 포메.jpg이미지는 포메라니로 추정됩니다.
# 11
# 해당 푸들.jpg이미지는 푸들로 추정됩니다.
# 12
# 해당 허스키.jpg이미지는 허스키로 추정됩니다.
